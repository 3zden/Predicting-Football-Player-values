# %% [markdown]
# # EXPLORATRY DATA ANALYSIS

# %% [markdown]
# #### importing Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns 
import os
import openpyxl

# %%
os.chdir('C:/Projects/Predicting Football Player Values/Data')

# %%
df = pd.read_csv('PlayersFBREF.csv')

# %% [markdown]
# ## General inspection

# %%
df = df.drop(columns=['Unnamed: 0', 'Player', 'Nation', 'Position'])
dfx = pd.read_excel('final_dataset.xlsx', engine='openpyxl')

df.head()
# Out:
#    Age  Matches Played  Starts Minutes  90s Played  Goals  Assists  \
# 0   32              38      38   3,371        37.5     29       18
# 1   33              37      37   3,330        37.0      3        1
# 2   22              37      37   3,160        35.1      0        4
# 3   25              35      30   2,599        28.9      5        5
# 4   25              31      30   2,560        28.4      1        2
#
#    Goals + Assists  Non-Penalty Goals  Penalty Goals Made  ...  Goals Per 90  \
# 0               47                 20                   9  ...          0.77
# 1                4                  3                   0  ...          0.08
# 2                4                  0                   0  ...          0.00
# 3               10                  5                   0  ...          0.17
# 4                3                  1                   0  ...          0.04
#
#    Assists Per 90  Goals + Assists Per 90  Non-Penalty Goals Per 90  \
# ...

# %%
# General inspection
print("Number of players:", df.shape[0] , "\nNumber of features:", df.shape[1], "\nFeatures:", df.columns.tolist(), "\nData types:", df.dtypes)
# Out:
# Number of players: 2274
# Number of features: 30
# Features: ['Age', 'Matches Played', 'Starts', 'Minutes', '90s Played', 'Goals', 'Assists', 'Goals + Assists', 'Non-Penalty Goals', 'Penalty Goals Made', 'Penalty Attempts', 'Yellow Cards', 'Red Cards', 'xG', 'npxG', 'xAG', 'npxG + xAG', 'Progressive Carries', 'Progressive Passes', 'Progressive Receives', 'Goals Per 90', 'Assists Per 90', 'Goals + Assists Per 90', 'Non-Penalty Goals Per 90', 'Non-Penalty Goals + Assists Per 90', 'xG Per 90', 'xAG Per 90', 'xG + xAG Per 90', 'npxG Per 90', 'npxG + xAG Per 90']
# Data types: Age                                     int64
# Matches Played                          int64
# Starts                                  int64
# Minutes                                object
# 90s Played                            float64
# Goals                                   int64
# Assists                                 int64
# Goals + Assists                         int64
# ...

# %%
dfattackers = df[df['Position'] == 'AT']
dfdefenders = df[df['Position'] == 'DF']
dfmidfielders = df[df['Position'] == 'MF'] 
dfgoalkeepers = df[df['Position'] == 'GK']

# %%
plt.scatter(df['xG Per 90'], df['Value'], alpha=0.5)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Projects\myenv\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Value'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[18], line 1
# ...

# %% [markdown]
# #### the influence of the features chnages from positon to another (e.g. xG Per 90 is less important for defenders, but a key feature for attackers), so its important to choose Top features for each position

# %%
corr = df.corr()
sns.heatmap(corr, annot=True, fmt=".2f", cmap='coolwarm', square=True, cbar_kws={"shrink": .8})
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 corr = df.corr()
#       2 sns.heatmap(corr, annot=True, fmt=".2f", cmap='coolwarm', square=True, cbar_kws={"shrink": .8})
#
# File c:\Projects\myenv\Lib\site-packages\pandas\core\frame.py:11056, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11054 cols = data.columns
#   11055 idx = cols.copy()
# > 11056 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11058 if method == "pearson":
#   11059     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File c:\Projects\myenv\Lib\site-packages\pandas\core\frame.py:1998, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1996 if dtype is not None:
#    1997     dtype = np.dtype(dtype)
# -> 1998 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1999 if result.dtype is not dtype:
# ...
