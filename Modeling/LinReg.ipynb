# %% [markdown]
# ## LinearRgression Model

# %% [markdown]
# ### importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.metrics import mean_squared_error, r2_score

# %% [markdown]
# ### import Datasets

# %%
PlayersFBREF = pd.read_csv('C:/Projects/Players fee prediction Project/Data/PlayersFBREF.csv')
PlayersFBREF.drop(columns=['Unnamed: 0'], inplace=True)
PlayersFBREF
# Out:
#                    Player Nation  ... npxG Per 90  npxG + xAG Per 90
# 0           Mohamed Salah    EGY  ...        0.49               0.87
# 1         Virgil van Dijk    NED  ...        0.06               0.08
# 2        Ryan Gravenberch    NED  ...        0.03               0.12
# 3     Alexis Mac Allister    ARG  ...        0.10               0.26
# 4         Ibrahima Konaté    FRA  ...        0.06               0.10
# ...                   ...    ...  ...         ...                ...
# 2269       Harvey Elliott    ENG  ...        0.43               0.69
# 2270          Wataru Endo    JPN  ...        0.00               0.02
# 2271      Federico Chiesa    ITA  ...        0.28               0.43
# 2272      Vitezslav Jaros    CZE  ...        0.00               0.00
# 2273         Jayden Danns    ENG  ...        0.00               0.00
#
# [2274 rows x 33 columns]
